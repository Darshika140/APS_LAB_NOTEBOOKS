# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshika140/APS_LAB_NOTEBOOKS/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    dist = {}
    prev = {}
    visited = []

    for node in graph:
        dist[node] = float('inf')
        prev[node] = None

    dist[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_dist = float('inf')

        for node in graph:
            if node not in visited and dist[node] < min_dist:
                min_dist = dist[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_dist = dist[min_node] + weight
            if new_dist < dist[neighbor]:
                dist[neighbor] = new_dist
                prev[neighbor] = min_node

    return dist, prev
def print_path(prev, start, node):
    path = []
    while node:
        path.append(node)
        node = prev[node]
    path.reverse()
    print(" -> ".join(path))

# %%
graph = {
    'A': {'B': 4, 'C': 2, 'F': 9},
    'B': {'A': 4, 'C': 5, 'D': 10, 'F': 7},
    'C': {'A': 2, 'B': 5, 'D': 3, 'E': 2},
    'D': {'B': 10, 'C': 3, 'E': 1},
    'E': {'C': 2, 'D': 1},
    'F': {'A': 9, 'B': 7},
    'G': {'E': 3, 'F': 8},
    'H': {'G': 2, 'D': 6}
}

start = input("Enter source node: ")
if start not in graph:
    print("Invalid node!")
else:
    dist, prev = dijkstra(graph, start)

    for node in graph:
        print(f"{start} -> {node} = {dist[node]}")
        print("Path:", end=" ")
        print_path(prev, start, node)
        print()
# Out:
# Enter source node: A
# A -> A = 0
# Path: A
#
# A -> B = 4
# Path: A -> B
#
# A -> C = 2
# Path: A -> C
#
# A -> D = 5
# Path: A -> C -> D
#
# A -> E = 4
# Path: A -> C -> E
#
# A -> F = 9
# Path: A -> F
#
# A -> G = inf
# Path: G
#
# A -> H = inf
# Path: H

# %% [markdown]
# # Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
